# %% [markdown]
# # Notice
#
# To have an accurate and dirct comparison, we use the following files from [ADAPT-VQE repository](https://github.com/mayhallgroup/adapt-vqe/tree/master/src)
# * `pyscf_helper.py` to create the Hamiltonian from the geometry
# * `operator_pools.py` to generate ansatz pool (as discussed in [ADAPT-GCIM paper](https://arxiv.org/abs/2312.07691))
#
#
# Due to upgrades in `openfermion`, `get_sparse_operator()` is not in `openfermion.transforms`. For `operator_pools.py`, at line 48, please replace `transforms.get_sparse_operator` to
# ```
# linalg.get_sparse_operator
# ```
#
# Due to upgrades in `pyscf`, `molden` is not in `pyscf` directly. In line 3 of `pyscf_helper.py`, please remove the import of `molden` and add the following at the top
# ```
# from pyscf.tools import molden
# ```
# If the atomic unit is used (such as $H_4$ and $H_6$ in [ADAPT-GCIM paper](https://arxiv.org/abs/2312.07691)), please add the following code in line 229 in `pyscf_helper.py`
# ```
# mol.unit = 'B'  # (B, b, Bohr, bohr, AU, au) or (A, a, Angstrom, angstrom, Ang, ang)
# ```

# %%
import numpy as np
import openfermion as of
try:
    import operator_pools
    import pyscf_helper
except:
    raise Except("See ReadMe. Please go to https://github.com/mayhallgroup/adapt-vqe/tree/master/src to download required files.")

## ADAPT-GCM
import adapt_gcim as ag
import moles

# %% [markdown]
# ## Construct the molecule and select GCIM inputs

# %% [markdown]
# The file `moles.py` records the geometries of the other molecules used in the paper. Please change the UNIT accordingly.
#
# To avoid numerical instability, we can use `make_orth=True` to orthogonalize the basis vector set classically. But to simulate quantum computing, this option should be `False`.
#
# As discussed in the paper, we do not optimize parameters in ADAPT-GCIM, so set `theta=np.pi/4` for all bases. Other good options for `theta` can be 0.001 etc.

# %%
## Option for the pool and GCM
mol = moles.LiH() # LiH, BeH2

make_orth = False # If classically orthogonalize the basis vector set
theta = np.pi/4 # constant phase parameter for all basis vectors

# %% [markdown]
# Let `PySCF` and `pyscf_helper.py` do the rest of the computation for the Hamiltonian

# %%
mol.initialize()
mol_name = mol.mol_name
mol_name_pic = mol.mol_name_pic
n_orb = mol.n_orb
n_a = mol.n_a
n_b = mol.n_b
fermi_ham = mol.fermi_ham
reference_ket = mol.reference_ket
file_prefix = 'Demo_Data/'
# Out:
#  ---------------------------------------------------------
#
#                       Using Pyscf:
#
#  ---------------------------------------------------------
#
# converged SCF energy = -7.86114942364805
#
# System and Method:
# [('Li', (0, 0, 0)), ('H', (0, 0, 1.62))]
# Basis set                                      :      sto-3g
# Number of Orbitals                             :         6
# Number of electrons                            :         4
# Nuclear Repulsion                              :    0.9799577980
# Electronic SCF energy                          :   -8.8411072216
# SCF Energy                                     :   -7.8611494236
#  AO->MO
#  NElectrons:    2    2
#  ecore:   0.00000000
#  ERIs in the active-space:
# (6, 6, 6, 6)    0.01036800 Mb
#  n_orb:    6
#  n_a  :    2
#  n_b  :    2
#  HF Energy:  -7.86114942
# /Users/zhen002/miniconda3/envs/gcimtest/lib/python3.11/site-packages/pyscf/lib/misc.py:146: UserWarning: OpenMP is not available. Setting omp_threads to 1 has no effects.
#   warnings.warn('OpenMP is not available. '
#  Build reference state with    2 alpha and    2 beta electrons [0, 2, 1, 3]
#  State    0:  -7.88194453 au

# %% [markdown]
# ## Select the operator pool
# By default, use the spin-adapted pool

# %%
pool = operator_pools.singlet_GSD()
pool.init(n_orb, n_occ_a=n_a, n_occ_b=n_b, n_vir_a=n_orb-n_a, n_vir_b=n_orb-n_b)
# Out:
#  Form singlet GSD operators
#  Number of operators:  330

# %% [markdown]
# ## Start ADAPT-GCIM
#
# `change_tol` is a convergence criteria. When the changes of the estimated ground-state energies are within `change_tol` for `X` amount of iterations, the algorithm declares convergence. The value of 'X' dependes on the size of pool. It is set to $10\%$ of the size of the pool in line 353 of `adapt_gcim.py` (i.e., variable `flat_iter`).
#
# In the fucntion return, `GCIM_EVS` records the lowest eigenvalues in all iterations, `OneShot_EV` records the eigenvalue from the final one-shot GCIM, `GCIM_Indices` is the indices of selected ansatzes in the operator pool, `GCIM_DIFFS` is the error of estimated ground-state energies in all iterations, `OneShot_Diff` is the error from one-shot GCIM, and `GCIM_BASIS_SIZE` is the size of bases in all iterations.

# %%
[GCIM_EVS,OneShot_EV, GCIM_Indices, GCIM_DIFFS, OneShot_Diff, GCIM_BASIS_SIZE] = ag.adapt_gcim(fermi_ham, 
                                pool,  reference_ket, theta,
                                change_tol    = 1e-6,
                                max_iter = 200,
                                make_orth = make_orth,
                                file_prefix  = file_prefix)
# Out:
#  Generate Sparse Matrices for operators in pool
#
#
# ------------ Iter 0 Start ------------
#  Sum of gradients = 0.200449
#  Largest gradient = 0.175572
#
#  Choose ansatz 193
#  Number of saved prod bases 0 , H matrix size (2, 2)
#    Eigensolver: dimension reduced from 2 to 2, with eigval > 1.000e-14
#  GCIM Energy:  -7.875951590107945
#  GCIM error : 5.992944e-03
# ------------ Iter 0 Finish -----------
#
#
# ------------ Iter 1 Start ------------
#  Sum of gradients = 0.113813
#  Largest gradient = 0.036321
#
#  Choose ansatz 191
#  Number of saved prod bases 1 , H matrix size (4, 4)
#    Eigensolver: dimension reduced from 4 to 3, with eigval > 1.000e-14
#  GCIM Energy:  -7.876589700913479
#  GCIM error : 5.354833e-03
# ------------ Iter 1 Finish -----------
#
#
# ------------ Iter 2 Start ------------
#  Sum of gradients = 0.201486
#  Largest gradient = 0.163237
#
#  Choose ansatz 328
#  Number of saved prod bases 2 , H matrix size (6, 6)
#    Eigensolver: dimension reduced from 6 to 3, with eigval > 1.000e-14
#  GCIM Energy:  -7.876589700913480
#  GCIM error : 5.354833e-03
# ------------ Iter 2 Finish -----------
#
#
# ------------ Iter 3 Start ------------
#  Sum of gradients = 0.108586
#  Largest gradient = 0.035333
#
#  Choose ansatz 35
#  Number of saved prod bases 3 , H matrix size (8, 8)
#    Eigensolver: dimension reduced from 8 to 4, with eigval > 1.000e-14
#  GCIM Energy:  -7.876771162506847
#  GCIM error : 5.173372e-03
# ------------ Iter 3 Finish -----------
#
#
# ------------ Iter 4 Start ------------
#  Sum of gradients = 0.455074
#  Largest gradient = 0.398502
#
#  Choose ansatz 215
#  Number of saved prod bases 4 , H matrix size (10, 10)
#    Eigensolver: dimension reduced from 10 to 5, with eigval > 1.000e-14
#  GCIM Energy:  -7.876773595926845
#  GCIM error : 5.170938e-03
# ------------ Iter 4 Finish -----------
#
#
# ------------ Iter 5 Start ------------
#  Sum of gradients = 0.133744
#  Largest gradient = 0.087922
#
#  Choose ansatz 184
#  Number of saved prod bases 5 , H matrix size (12, 12)
#    Eigensolver: dimension reduced from 12 to 5, with eigval > 1.000e-14
#  GCIM Energy:  -7.876773595926842
#  GCIM error : 5.170938e-03
# ------------ Iter 5 Finish -----------
#
#
# ------------ Iter 6 Start ------------
#  Sum of gradients = 0.230329
#  Largest gradient = 0.172747
#  Small changes have happended for 0/32 iterations
#
#  Choose ansatz 278
#  Number of saved prod bases 6 , H matrix size (14, 14)
#    Eigensolver: dimension reduced from 14 to 5, with eigval > 1.000e-14
#  GCIM Energy:  -7.876773595926841
#  GCIM error : 5.170938e-03
# ------------ Iter 6 Finish -----------
#
#
# ------------ Iter 7 Start ------------
#  Sum of gradients = 0.078450
#  Largest gradient = 0.034091
#  Small changes have happended for 1/32 iterations
#
#  Choose ansatz 316
#  Number of saved prod bases 7 , H matrix size (16, 16)
#    Eigensolver: dimension reduced from 16 to 6, with eigval > 1.000e-14
#  GCIM Energy:  -7.877327463921402
#  GCIM error : 4.617070e-03
# ------------ Iter 7 Finish -----------
#
#
# ------------ Iter 8 Start ------------
#  Sum of gradients = 0.138732
#  Largest gradient = 0.108219
#
#  Choose ansatz 188
#  Number of saved prod bases 8 , H matrix size (18, 18)
#    Eigensolver: dimension reduced from 18 to 6, with eigval > 1.000e-14
#  GCIM Energy:  -7.877327463921405
#  GCIM error : 4.617070e-03
# ------------ Iter 8 Finish -----------
#
#
# ------------ Iter 9 Start ------------
#  Sum of gradients = 0.082350
#  Largest gradient = 0.038770
#  Small changes have happended for 0/32 iterations
#
#  Choose ansatz 5
#  Number of saved prod bases 9 , H matrix size (20, 20)
#    Eigensolver: dimension reduced from 20 to 6, with eigval > 1.000e-14
#  GCIM Energy:  -7.877327463921406
#  GCIM error : 4.617070e-03
# ------------ Iter 9 Finish -----------
#
#
# ------------ Iter 10 Start ------------
#  Sum of gradients = 0.150955
#  Largest gradient = 0.072566
#  Small changes have happended for 1/32 iterations
#
#  Choose ansatz 72
#  Number of saved prod bases 10 , H matrix size (22, 22)
#    Eigensolver: dimension reduced from 22 to 7, with eigval > 1.000e-14
#  GCIM Energy:  -7.881339608305009
#  GCIM error : 6.049257e-04
# ------------ Iter 10 Finish -----------
#
#
# ------------ Iter 11 Start ------------
#  Sum of gradients = 0.403063
#  Largest gradient = 0.217116
#
#  Choose ansatz 11
#  Number of saved prod bases 11 , H matrix size (24, 24)
#    Eigensolver: dimension reduced from 24 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846296
#  GCIM error : 2.292422e-04
# ------------ Iter 11 Finish -----------
#
#
# ------------ Iter 12 Start ------------
#  Sum of gradients = 0.153567
#  Largest gradient = 0.096471
#
#  Choose ansatz 311
#  Number of saved prod bases 12 , H matrix size (26, 26)
#    Eigensolver: dimension reduced from 26 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846370
#  GCIM error : 2.292422e-04
# ------------ Iter 12 Finish -----------
#
#
# ------------ Iter 13 Start ------------
#  Sum of gradients = 0.315619
#  Largest gradient = 0.183787
#  Small changes have happended for 0/31 iterations
#
#  Choose ansatz 73
#  Number of saved prod bases 13 , H matrix size (28, 28)
#    Eigensolver: dimension reduced from 28 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846362
#  GCIM error : 2.292422e-04
# ------------ Iter 13 Finish -----------
#
#
# ------------ Iter 14 Start ------------
#  Sum of gradients = 0.339126
#  Largest gradient = 0.193922
#  Small changes have happended for 1/31 iterations
#
#  Choose ansatz 187
#  Number of saved prod bases 14 , H matrix size (30, 30)
#    Eigensolver: dimension reduced from 30 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846362
#  GCIM error : 2.292422e-04
# ------------ Iter 14 Finish -----------
#
#
# ------------ Iter 15 Start ------------
#  Sum of gradients = 0.172175
#  Largest gradient = 0.074798
#  Small changes have happended for 2/31 iterations
#
#  Choose ansatz 41
#  Number of saved prod bases 15 , H matrix size (32, 32)
#    Eigensolver: dimension reduced from 32 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846368
#  GCIM error : 2.292422e-04
# ------------ Iter 15 Finish -----------
#
#
# ------------ Iter 16 Start ------------
#  Sum of gradients = 0.278400
#  Largest gradient = 0.185554
#  Small changes have happended for 3/31 iterations
#
#  Choose ansatz 8
#  Number of saved prod bases 16 , H matrix size (34, 34)
#    Eigensolver: dimension reduced from 34 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846363
#  GCIM error : 2.292422e-04
# ------------ Iter 16 Finish -----------
#
#
# ------------ Iter 17 Start ------------
#  Sum of gradients = 0.123270
#  Largest gradient = 0.059478
#  Small changes have happended for 4/31 iterations
#
#  Choose ansatz 206
#  Number of saved prod bases 17 , H matrix size (36, 36)
#    Eigensolver: dimension reduced from 36 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846363
#  GCIM error : 2.292422e-04
# ------------ Iter 17 Finish -----------
#
#
# ------------ Iter 18 Start ------------
#  Sum of gradients = 0.109768
#  Largest gradient = 0.050933
#  Small changes have happended for 5/31 iterations
#
#  Choose ansatz 180
#  Number of saved prod bases 18 , H matrix size (38, 38)
#    Eigensolver: dimension reduced from 38 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846361
#  GCIM error : 2.292422e-04
# ------------ Iter 18 Finish -----------
#
#
# ------------ Iter 19 Start ------------
#  Sum of gradients = 0.161108
#  Largest gradient = 0.084495
#  Small changes have happended for 6/31 iterations
#
#  Choose ansatz 36
#  Number of saved prod bases 19 , H matrix size (40, 40)
#    Eigensolver: dimension reduced from 40 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846364
#  GCIM error : 2.292422e-04
# ------------ Iter 19 Finish -----------
#
#
# ------------ Iter 20 Start ------------
#  Sum of gradients = 0.164534
#  Largest gradient = 0.088108
#  Small changes have happended for 7/31 iterations
#
#  Choose ansatz 200
#  Number of saved prod bases 20 , H matrix size (42, 42)
#    Eigensolver: dimension reduced from 42 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846360
#  GCIM error : 2.292422e-04
# ------------ Iter 20 Finish -----------
#
#
# ------------ Iter 21 Start ------------
#  Sum of gradients = 0.134693
#  Largest gradient = 0.045882
#  Small changes have happended for 8/30 iterations
#
#  Choose ansatz 276
#  Number of saved prod bases 21 , H matrix size (44, 44)
#    Eigensolver: dimension reduced from 44 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846358
#  GCIM error : 2.292422e-04
# ------------ Iter 21 Finish -----------
#
#
# ------------ Iter 22 Start ------------
#  Sum of gradients = 0.119255
#  Largest gradient = 0.043653
#  Small changes have happended for 9/30 iterations
#
#  Choose ansatz 314
#  Number of saved prod bases 22 , H matrix size (46, 46)
#    Eigensolver: dimension reduced from 46 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846365
#  GCIM error : 2.292422e-04
# ------------ Iter 22 Finish -----------
#
#
# ------------ Iter 23 Start ------------
#  Sum of gradients = 0.104718
#  Largest gradient = 0.031581
#  Small changes have happended for 10/30 iterations
#
#  Choose ansatz 183
#  Number of saved prod bases 23 , H matrix size (48, 48)
#    Eigensolver: dimension reduced from 48 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846369
#  GCIM error : 2.292422e-04
# ------------ Iter 23 Finish -----------
#
#
# ------------ Iter 24 Start ------------
#  Sum of gradients = 0.173977
#  Largest gradient = 0.124991
#  Small changes have happended for 11/30 iterations
#
#  Choose ansatz 42
#  Number of saved prod bases 24 , H matrix size (50, 50)
#    Eigensolver: dimension reduced from 50 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846361
#  GCIM error : 2.292422e-04
# ------------ Iter 24 Finish -----------
#
#
# ------------ Iter 25 Start ------------
#  Sum of gradients = 0.137124
#  Largest gradient = 0.081085
#  Small changes have happended for 12/30 iterations
#
#  Choose ansatz 269
#  Number of saved prod bases 25 , H matrix size (52, 52)
#    Eigensolver: dimension reduced from 52 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846363
#  GCIM error : 2.292422e-04
# ------------ Iter 25 Finish -----------
#
#
# ------------ Iter 26 Start ------------
#  Sum of gradients = 0.109533
#  Largest gradient = 0.040421
#  Small changes have happended for 13/30 iterations
#
#  Choose ansatz 212
#  Number of saved prod bases 26 , H matrix size (54, 54)
#    Eigensolver: dimension reduced from 54 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846365
#  GCIM error : 2.292422e-04
# ------------ Iter 26 Finish -----------
#
#
# ------------ Iter 27 Start ------------
#  Sum of gradients = 0.099500
#  Largest gradient = 0.036920
#  Small changes have happended for 14/30 iterations
#
#  Choose ansatz 308
#  Number of saved prod bases 27 , H matrix size (56, 56)
#    Eigensolver: dimension reduced from 56 to 8, with eigval > 1.000e-14
#  GCIM Energy:  -7.881715291846363
#  GCIM error : 2.292422e-04
# ------------ Iter 27 Finish -----------
#
#
# ------------ Iter 28 Start ------------
#  Sum of gradients = 0.089394
#  Largest gradient = 0.025702
#  Small changes have happended for 15/30 iterations
#
#  Choose ansatz 1
#  Number of saved prod bases 28 , H matrix size (58, 58)
#    Eigensolver: dimension reduced from 58 to 10, with eigval > 1.000e-14
#  GCIM Energy:  -7.881729440555484
#  GCIM error : 2.150935e-04
# ------------ Iter 28 Finish -----------
#
#
# ------------ Iter 29 Start ------------
#  Sum of gradients = 2.002463
#  Largest gradient = 0.863843
#
#  Choose ansatz 16
#  Number of saved prod bases 29 , H matrix size (60, 60)
#    Eigensolver: dimension reduced from 60 to 12, with eigval > 1.000e-14
#  GCIM Energy:  -7.881792692028383
#  GCIM error : 1.518420e-04
# ------------ Iter 29 Finish -----------
#
#
# ------------ Iter 30 Start ------------
#  Sum of gradients = 0.859234
#  Largest gradient = 0.657392
#
#  Choose ansatz 25
#  Number of saved prod bases 30 , H matrix size (62, 62)
#    Eigensolver: dimension reduced from 62 to 13, with eigval > 1.000e-14
#  GCIM Energy:  -7.881792985189092
#  GCIM error : 1.515488e-04
# ------------ Iter 30 Finish -----------
#
#
# ------------ Iter 31 Start ------------
#  Sum of gradients = 2.276431
#  Largest gradient = 1.453190
#  Small changes have happended for 0/29 iterations
#
#  Choose ansatz 28
#  Number of saved prod bases 31 , H matrix size (64, 64)
#    Eigensolver: dimension reduced from 64 to 15, with eigval > 1.000e-14
#  GCIM Energy:  -7.881794139751113
#  GCIM error : 1.503943e-04
# ------------ Iter 31 Finish -----------
#
#
# ------------ Iter 32 Start ------------
#  Sum of gradients = 2.183829
#  Largest gradient = 2.037437
#
#  Choose ansatz 34
#  Number of saved prod bases 32 , H matrix size (66, 66)
#    Eigensolver: dimension reduced from 66 to 17, with eigval > 1.000e-14
#  GCIM Energy:  -7.881801859923015
#  GCIM error : 1.426741e-04
# ------------ Iter 32 Finish -----------
#
#
# ------------ Iter 33 Start ------------
#  Sum of gradients = 0.504980
#  Largest gradient = 0.326934
#
#  Choose ansatz 29
#  Number of saved prod bases 33 , H matrix size (68, 68)
#    Eigensolver: dimension reduced from 68 to 19, with eigval > 1.000e-14
#  GCIM Energy:  -7.881818531987550
#  GCIM error : 1.260020e-04
# ------------ Iter 33 Finish -----------
#
#
# ------------ Iter 34 Start ------------
#  Sum of gradients = 0.502236
#  Largest gradient = 0.420837
#
#  Choose ansatz 20
#  Number of saved prod bases 34 , H matrix size (70, 70)
#    Eigensolver: dimension reduced from 70 to 20, with eigval > 1.000e-14
#  GCIM Energy:  -7.881833870996350
#  GCIM error : 1.106630e-04
# ------------ Iter 34 Finish -----------
#
#
# ------------ Iter 35 Start ------------
#  Sum of gradients = 0.289933
#  Largest gradient = 0.117845
#
#  Choose ansatz 83
#  Number of saved prod bases 35 , H matrix size (72, 72)
#    Eigensolver: dimension reduced from 72 to 21, with eigval > 1.000e-14
#  GCIM Energy:  -7.881833909013404
#  GCIM error : 1.106250e-04
# ------------ Iter 35 Finish -----------
#
#
# ------------ Iter 36 Start ------------
#  Sum of gradients = 2.133530
#  Largest gradient = 1.671348
#  Small changes have happended for 0/29 iterations
#
#  Choose ansatz 169
#  Number of saved prod bases 36 , H matrix size (74, 74)
#    Eigensolver: dimension reduced from 74 to 22, with eigval > 1.000e-14
#  GCIM Energy:  -7.881833909137153
#  GCIM error : 1.106249e-04
# ------------ Iter 36 Finish -----------
#
#
# ------------ Iter 37 Start ------------
#  Sum of gradients = 1.263834
#  Largest gradient = 0.883777
#  Small changes have happended for 1/29 iterations
#
#  Choose ansatz 170
#  Number of saved prod bases 37 , H matrix size (76, 76)
#    Eigensolver: dimension reduced from 76 to 23, with eigval > 1.000e-14
#  GCIM Energy:  -7.881837288716432
#  GCIM error : 1.072453e-04
# ------------ Iter 37 Finish -----------
#
#
# ------------ Iter 38 Start ------------
#  Sum of gradients = 0.855126
#  Largest gradient = 0.378752
#
#  Choose ansatz 74
#  Number of saved prod bases 38 , H matrix size (78, 78)
#    Eigensolver: dimension reduced from 78 to 24, with eigval > 1.000e-14
#  GCIM Energy:  -7.881837528473679
#  GCIM error : 1.070056e-04
# ------------ Iter 38 Finish -----------
#
#
# ------------ Iter 39 Start ------------
#  Sum of gradients = 0.787358
#  Largest gradient = 0.459739
#  Small changes have happended for 0/29 iterations
#
#  Choose ansatz 171
#  Number of saved prod bases 39 , H matrix size (80, 80)
#    Eigensolver: dimension reduced from 80 to 25, with eigval > 1.000e-14
#  GCIM Energy:  -7.881837529791142
#  GCIM error : 1.070042e-04
# ------------ Iter 39 Finish -----------
#
#
# ------------ Iter 40 Start ------------
#  Sum of gradients = 0.619355
#  Largest gradient = 0.293028
#  Small changes have happended for 1/29 iterations
#
#  Choose ansatz 90
#  Number of saved prod bases 40 , H matrix size (82, 82)
#    Eigensolver: dimension reduced from 82 to 26, with eigval > 1.000e-14
#  GCIM Energy:  -7.881839415956899
#  GCIM error : 1.051181e-04
# ------------ Iter 40 Finish -----------
#
#
# ------------ Iter 41 Start ------------
#  Sum of gradients = 0.649518
#  Largest gradient = 0.282018
#
#  Choose ansatz 122
#  Number of saved prod bases 41 , H matrix size (84, 84)
#    Eigensolver: dimension reduced from 84 to 27, with eigval > 1.000e-14
#  GCIM Energy:  -7.881845076133515
#  GCIM error : 9.945789e-05
# ------------ Iter 41 Finish -----------
#
#
# ------------ Iter 42 Start ------------
#  Sum of gradients = 0.545867
#  Largest gradient = 0.234367
#
#  Choose ansatz 44
#  Number of saved prod bases 42 , H matrix size (86, 86)
#    Eigensolver: dimension reduced from 86 to 28, with eigval > 1.000e-14
#  GCIM Energy:  -7.881845837142747
#  GCIM error : 9.869689e-05
# ------------ Iter 42 Finish -----------
#
#
# ------------ Iter 43 Start ------------
#  Sum of gradients = 0.476810
#  Largest gradient = 0.193087
#  Small changes have happended for 0/28 iterations
#
#  Choose ansatz 32
#  Number of saved prod bases 43 , H matrix size (88, 88)
#    Eigensolver: dimension reduced from 88 to 29, with eigval > 1.000e-14
#  GCIM Energy:  -7.881846353163056
#  GCIM error : 9.818086e-05
# ------------ Iter 43 Finish -----------
#
#
# ------------ Iter 44 Start ------------
#  Sum of gradients = 0.930901
#  Largest gradient = 0.833153
#  Small changes have happended for 1/28 iterations
#
#  Choose ansatz 95
#  Number of saved prod bases 44 , H matrix size (90, 90)
#    Eigensolver: dimension reduced from 90 to 30, with eigval > 1.000e-14
#  GCIM Energy:  -7.881846424369465
#  GCIM error : 9.810966e-05
# ------------ Iter 44 Finish -----------
#
#
# ------------ Iter 45 Start ------------
#  Sum of gradients = 0.504138
#  Largest gradient = 0.183332
#  Small changes have happended for 2/28 iterations
#
#  Choose ansatz 88
#  Number of saved prod bases 45 , H matrix size (92, 92)
#    Eigensolver: dimension reduced from 92 to 31, with eigval > 1.000e-14
#  GCIM Energy:  -7.881846665646109
#  GCIM error : 9.786838e-05
# ------------ Iter 45 Finish -----------
#
#
# ------------ Iter 46 Start ------------
#  Sum of gradients = 0.650114
#  Largest gradient = 0.280318
#  Small changes have happended for 3/28 iterations
#
#  Choose ansatz 4
#  Number of saved prod bases 46 , H matrix size (94, 94)
#    Eigensolver: dimension reduced from 94 to 33, with eigval > 1.000e-14
#  GCIM Energy:  -7.881847025924176
#  GCIM error : 9.750810e-05
# ------------ Iter 46 Finish -----------
#
#
# ------------ Iter 47 Start ------------
#  Sum of gradients = 0.810766
#  Largest gradient = 0.399351
#  Small changes have happended for 4/28 iterations
#
#  Choose ansatz 179
#  Number of saved prod bases 47 , H matrix size (96, 96)
#    Eigensolver: dimension reduced from 96 to 34, with eigval > 1.000e-14
#  GCIM Energy:  -7.881847194940555
#  GCIM error : 9.733909e-05
# ------------ Iter 47 Finish -----------
#
#
# ------------ Iter 48 Start ------------
#  Sum of gradients = 0.568419
#  Largest gradient = 0.270102
#  Small changes have happended for 5/28 iterations
#
#  Choose ansatz 98
#  Number of saved prod bases 48 , H matrix size (98, 98)
#    Eigensolver: dimension reduced from 98 to 35, with eigval > 1.000e-14
#  GCIM Energy:  -7.881856949478877
#  GCIM error : 8.758455e-05
# ------------ Iter 48 Finish -----------
#
#
# ------------ Iter 49 Start ------------
#  Sum of gradients = 0.495445
#  Largest gradient = 0.226293
#
#  Choose ansatz 164
#  Number of saved prod bases 49 , H matrix size (100, 100)
#    Eigensolver: dimension reduced from 100 to 36, with eigval > 1.000e-14
#  GCIM Energy:  -7.881870501612328
#  GCIM error : 7.403242e-05
# ------------ Iter 49 Finish -----------
#
#
# ------------ Iter 50 Start ------------
#  Sum of gradients = 0.480240
#  Largest gradient = 0.196311
#
#  Choose ansatz 176
#  Number of saved prod bases 50 , H matrix size (102, 102)
#    Eigensolver: dimension reduced from 102 to 37, with eigval > 1.000e-14
#  GCIM Energy:  -7.881876548574139
#  GCIM error : 6.798545e-05
# ------------ Iter 50 Finish -----------
#
#
# ------------ Iter 51 Start ------------
#  Sum of gradients = 0.574191
#  Largest gradient = 0.245899
#
#  Choose ansatz 152
#  Number of saved prod bases 51 , H matrix size (104, 104)
#    Eigensolver: dimension reduced from 104 to 38, with eigval > 1.000e-14
#  GCIM Energy:  -7.881881495528609
#  GCIM error : 6.303850e-05
# ------------ Iter 51 Finish -----------
#
#
# ------------ Iter 52 Start ------------
#  Sum of gradients = 0.489332
#  Largest gradient = 0.190280
#
#  Choose ansatz 50
#  Number of saved prod bases 52 , H matrix size (106, 106)
#    Eigensolver: dimension reduced from 106 to 39, with eigval > 1.000e-14
#  GCIM Energy:  -7.881900911604636
#  GCIM error : 4.362242e-05
# ------------ Iter 52 Finish -----------
#
#
# ------------ Iter 53 Start ------------
#  Sum of gradients = 0.472405
#  Largest gradient = 0.172514
#
#  Choose ansatz 113
#  Number of saved prod bases 53 , H matrix size (108, 108)
#    Eigensolver: dimension reduced from 108 to 40, with eigval > 1.000e-14
#  GCIM Energy:  -7.881904029419212
#  GCIM error : 4.050461e-05
# ------------ Iter 53 Finish -----------
#
#
# ------------ Iter 54 Start ------------
#  Sum of gradients = 0.398422
#  Largest gradient = 0.152683
#
#  Choose ansatz 162
#  Number of saved prod bases 54 , H matrix size (110, 110)
#    Eigensolver: dimension reduced from 110 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534032592
#  GCIM error : 4.764189e-12
# ------------ Iter 54 Finish -----------
#
#
# ------------ Iter 55 Start ------------
#  Sum of gradients = 1.280385
#  Largest gradient = 0.713966
#
#  Choose ansatz 21
#  Number of saved prod bases 55 , H matrix size (112, 112)
#    Eigensolver: dimension reduced from 112 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027783
#  GCIM error : 4.529710e-14
# ------------ Iter 55 Finish -----------
#
#
# ------------ Iter 56 Start ------------
#  Sum of gradients = 0.693958
#  Largest gradient = 0.366084
#  Small changes have happended for 0/27 iterations
#
#  Choose ansatz 0
#  Number of saved prod bases 56 , H matrix size (114, 114)
#    Eigensolver: dimension reduced from 114 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027785
#  GCIM error : 4.263256e-14
# ------------ Iter 56 Finish -----------
#
#
# ------------ Iter 57 Start ------------
#  Sum of gradients = 0.849831
#  Largest gradient = 0.424549
#  Small changes have happended for 1/27 iterations
#
#  Choose ansatz 163
#  Number of saved prod bases 57 , H matrix size (116, 116)
#    Eigensolver: dimension reduced from 116 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027789
#  GCIM error : 3.907985e-14
# ------------ Iter 57 Finish -----------
#
#
# ------------ Iter 58 Start ------------
#  Sum of gradients = 0.644008
#  Largest gradient = 0.388188
#  Small changes have happended for 2/27 iterations
#
#  Choose ansatz 67
#  Number of saved prod bases 58 , H matrix size (118, 118)
#    Eigensolver: dimension reduced from 118 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027786
#  GCIM error : 4.174439e-14
# ------------ Iter 58 Finish -----------
#
#
# ------------ Iter 59 Start ------------
#  Sum of gradients = 0.465035
#  Largest gradient = 0.160715
#  Small changes have happended for 3/27 iterations
#
#  Choose ansatz 58
#  Number of saved prod bases 59 , H matrix size (120, 120)
#    Eigensolver: dimension reduced from 120 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027794
#  GCIM error : 3.375078e-14
# ------------ Iter 59 Finish -----------
#
#
# ------------ Iter 60 Start ------------
#  Sum of gradients = 0.686384
#  Largest gradient = 0.405607
#  Small changes have happended for 4/27 iterations
#
#  Choose ansatz 24
#  Number of saved prod bases 60 , H matrix size (122, 122)
#    Eigensolver: dimension reduced from 122 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027800
#  GCIM error : 2.842171e-14
# ------------ Iter 60 Finish -----------
#
#
# ------------ Iter 61 Start ------------
#  Sum of gradients = 0.667227
#  Largest gradient = 0.358316
#  Small changes have happended for 5/26 iterations
#
#  Choose ansatz 57
#  Number of saved prod bases 61 , H matrix size (124, 124)
#    Eigensolver: dimension reduced from 124 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027789
#  GCIM error : 3.907985e-14
# ------------ Iter 61 Finish -----------
#
#
# ------------ Iter 62 Start ------------
#  Sum of gradients = 0.612348
#  Largest gradient = 0.256277
#  Small changes have happended for 6/26 iterations
#
#  Choose ansatz 64
#  Number of saved prod bases 62 , H matrix size (126, 126)
#    Eigensolver: dimension reduced from 126 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027776
#  GCIM error : 5.240253e-14
# ------------ Iter 62 Finish -----------
#
#
# ------------ Iter 63 Start ------------
#  Sum of gradients = 0.503033
#  Largest gradient = 0.217692
#  Small changes have happended for 7/26 iterations
#
#  Choose ansatz 59
#  Number of saved prod bases 63 , H matrix size (128, 128)
#    Eigensolver: dimension reduced from 128 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027803
#  GCIM error : 2.486900e-14
# ------------ Iter 63 Finish -----------
#
#
# ------------ Iter 64 Start ------------
#  Sum of gradients = 0.509014
#  Largest gradient = 0.216298
#  Small changes have happended for 8/26 iterations
#
#  Choose ansatz 153
#  Number of saved prod bases 64 , H matrix size (130, 130)
#    Eigensolver: dimension reduced from 130 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027802
#  GCIM error : 2.575717e-14
# ------------ Iter 64 Finish -----------
#
#
# ------------ Iter 65 Start ------------
#  Sum of gradients = 0.472246
#  Largest gradient = 0.178338
#  Small changes have happended for 9/26 iterations
#
#  Choose ansatz 135
#  Number of saved prod bases 65 , H matrix size (132, 132)
#    Eigensolver: dimension reduced from 132 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027789
#  GCIM error : 3.907985e-14
# ------------ Iter 65 Finish -----------
#
#
# ------------ Iter 66 Start ------------
#  Sum of gradients = 0.489821
#  Largest gradient = 0.200870
#  Small changes have happended for 10/26 iterations
#
#  Choose ansatz 136
#  Number of saved prod bases 66 , H matrix size (134, 134)
#    Eigensolver: dimension reduced from 134 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027787
#  GCIM error : 4.085621e-14
# ------------ Iter 66 Finish -----------
#
#
# ------------ Iter 67 Start ------------
#  Sum of gradients = 0.496138
#  Largest gradient = 0.325566
#  Small changes have happended for 11/26 iterations
#
#  Choose ansatz 51
#  Number of saved prod bases 67 , H matrix size (136, 136)
#    Eigensolver: dimension reduced from 136 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027793
#  GCIM error : 3.463896e-14
# ------------ Iter 67 Finish -----------
#
#
# ------------ Iter 68 Start ------------
#  Sum of gradients = 0.491220
#  Largest gradient = 0.215241
#  Small changes have happended for 12/26 iterations
#
#  Choose ansatz 142
#  Number of saved prod bases 68 , H matrix size (138, 138)
#    Eigensolver: dimension reduced from 138 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027795
#  GCIM error : 3.286260e-14
# ------------ Iter 68 Finish -----------
#
#
# ------------ Iter 69 Start ------------
#  Sum of gradients = 0.389605
#  Largest gradient = 0.226066
#  Small changes have happended for 13/26 iterations
#
#  Choose ansatz 52
#  Number of saved prod bases 69 , H matrix size (140, 140)
#    Eigensolver: dimension reduced from 140 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027796
#  GCIM error : 3.197442e-14
# ------------ Iter 69 Finish -----------
#
#
# ------------ Iter 70 Start ------------
#  Sum of gradients = 0.215114
#  Largest gradient = 0.109840
#  Small changes have happended for 14/26 iterations
#
#  Choose ansatz 89
#  Number of saved prod bases 70 , H matrix size (142, 142)
#    Eigensolver: dimension reduced from 142 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027790
#  GCIM error : 3.819167e-14
# ------------ Iter 70 Finish -----------
#
#
# ------------ Iter 71 Start ------------
#  Sum of gradients = 0.290655
#  Largest gradient = 0.182074
#  Small changes have happended for 15/25 iterations
#
#  Choose ansatz 156
#  Number of saved prod bases 71 , H matrix size (144, 144)
#    Eigensolver: dimension reduced from 144 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027786
#  GCIM error : 4.174439e-14
# ------------ Iter 71 Finish -----------
#
#
# ------------ Iter 72 Start ------------
#  Sum of gradients = 0.389217
#  Largest gradient = 0.286629
#  Small changes have happended for 16/25 iterations
#
#  Choose ansatz 45
#  Number of saved prod bases 72 , H matrix size (146, 146)
#    Eigensolver: dimension reduced from 146 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027785
#  GCIM error : 4.263256e-14
# ------------ Iter 72 Finish -----------
#
#
# ------------ Iter 73 Start ------------
#  Sum of gradients = 0.252811
#  Largest gradient = 0.101756
#  Small changes have happended for 17/25 iterations
#
#  Choose ansatz 76
#  Number of saved prod bases 73 , H matrix size (148, 148)
#    Eigensolver: dimension reduced from 148 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027784
#  GCIM error : 4.352074e-14
# ------------ Iter 73 Finish -----------
#
#
# ------------ Iter 74 Start ------------
#  Sum of gradients = 0.330879
#  Largest gradient = 0.197529
#  Small changes have happended for 18/25 iterations
#
#  Choose ansatz 82
#  Number of saved prod bases 74 , H matrix size (150, 150)
#    Eigensolver: dimension reduced from 150 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027794
#  GCIM error : 3.375078e-14
# ------------ Iter 74 Finish -----------
#
#
# ------------ Iter 75 Start ------------
#  Sum of gradients = 0.296121
#  Largest gradient = 0.132461
#  Small changes have happended for 19/25 iterations
#
#  Choose ansatz 75
#  Number of saved prod bases 75 , H matrix size (152, 152)
#    Eigensolver: dimension reduced from 152 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027790
#  GCIM error : 3.819167e-14
# ------------ Iter 75 Finish -----------
#
#
# ------------ Iter 76 Start ------------
#  Sum of gradients = 0.354028
#  Largest gradient = 0.209574
#  Small changes have happended for 20/25 iterations
#
#  Choose ansatz 81
#  Number of saved prod bases 76 , H matrix size (154, 154)
#    Eigensolver: dimension reduced from 154 to 41, with eigval > 2.000e-14
#  GCIM Energy:  -7.881944534027784
#  GCIM error : 4.440892e-14
# ------------ Iter 76 Finish -----------
#
#
# ------------ Iter 77 Start ------------
#  Sum of gradients = 0.384180
#  Largest gradient = 0.300586
#  Small changes have happended for 21/25 iterations
#
#  Choose ansatz 43
#  Number of saved prod bases 77 , H matrix size (156, 156)
#    Eigensolver: dimension reduced from 156 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027798
#  GCIM error : 3.019807e-14
# ------------ Iter 77 Finish -----------
#
#
# ------------ Iter 78 Start ------------
#  Sum of gradients = 0.331325
#  Largest gradient = 0.180750
#  Small changes have happended for 22/25 iterations
#
#  Choose ansatz 15
#  Number of saved prod bases 78 , H matrix size (158, 158)
#    Eigensolver: dimension reduced from 158 to 41, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027796
#  GCIM error : 3.197442e-14
# ------------ Iter 78 Finish -----------
#
#
# ------------ Iter 79 Start ------------
#  Sum of gradients = 0.311986
#  Largest gradient = 0.185595
#  Small changes have happended for 23/25 iterations
#
#  Choose ansatz 155
#  Number of saved prod bases 79 , H matrix size (160, 160)
#    Eigensolver: dimension reduced from 160 to 42, with eigval > 1.000e-14
#  GCIM Energy:  -7.881944534027802
#  GCIM error : 2.575717e-14
# ------------ Iter 79 Finish -----------
#
#
# ------------ Iter 80 Start ------------
#  Sum of gradients = 0.384688
#  Largest gradient = 0.311557
#  Small changes have happended for 24/25 iterations
#  Converged due to tiny changes 6.217e-15 in eigenvalues in 25 iterations
#  ADAPT-GCIM Converged
#  Orthogonalization:  False
#    Eigensolver: dimension reduced from 82 to 22, with eigval > 1.000e-14
#  Number of ansatzes:  80
#  Number of basis used in the final iteration of GCM: 160
#  Number of basis used in the one-shot GCM : 82
#  *True Energy :  -7.881944534027828
#  *GCIM Finished:  -7.881944534027802
#  *GCIM error          2.575717e-14
#  *One-shot GCIM error 1.312205e-05
#  ----------- Final ansatzes -----------
#     #        Coeff               Term
#     0   0.78539816      (1' 1' 5  5  ) : 1010 1010
#     1   0.78539816      (1' 1' 4  4  ) : 1010 1010
#     2   0.78539816      (4' 4' 5  5  ) : 1010 1010
#     3   0.78539816      (1' 0' 2  0  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#     4   0.78539816      (2' 1' 5  5  ) : 1010 1001 1010 0110
#     5   0.78539816      (1' 1' 2  2  ) : 1010 1010
#     6   0.78539816      (2' 2' 5  5  ) : 1010 1010
#     7   0.78539816      (3' 3' 5  5  ) : 1010 1010
#     8   0.78539816      (1' 1' 3  3  ) : 1010 1010
#     9   0.78539816            (2' 1  ) : 00 11 00 11
#    10   0.78539816      (2' 0' 5  0  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    11   0.78539816            (5' 2  ) : 00 11 00 11
#    12   0.78539816      (5' 2' 5  5  ) : 1010 1001 1010 0110
#    13   0.78539816      (2' 0' 5  0  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    14   0.78539816      (1' 1' 5  2  ) : 1010 0110 1010 1001
#    15   0.78539816      (1' 0' 5  0  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    16   0.78539816            (5' 1  ) : 00 11 00 11
#    17   0.78539816      (2' 1' 5  2  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    18   0.78539816      (1' 1' 2  1  ) : 1010 0110 1010 1001
#    19   0.78539816      (1' 0' 2  0  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    20   0.78539816      (2' 1' 2  2  ) : 1010 1001 1010 0110
#    21   0.78539816      (2' 2' 4  4  ) : 1010 1010
#    22   0.78539816      (3' 3' 4  4  ) : 1010 1010
#    23   0.78539816      (1' 1' 5  1  ) : 1010 0110 1010 1001
#    24   0.78539816      (1' 0' 5  0  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    25   0.78539816      (5' 1' 5  5  ) : 1010 1001 1010 0110
#    26   0.78539816      (2' 1' 4  4  ) : 1010 1001 1010 0110
#    27   0.78539816      (5' 2' 4  4  ) : 1010 1001 1010 0110
#    28   0.78539816            (2' 0  ) : 00 11 00 11
#    29   0.78539816      (0' 0' 2  0  ) : 1010 0110 1010 1001
#    30   0.78539816      (0' 0' 2  2  ) : 1010 1010
#    31   0.78539816      (0' 0' 5  2  ) : 1010 0110 1010 1001
#    32   0.78539816      (0' 0' 5  5  ) : 1010 1010
#    33   0.78539816      (0' 0' 3  3  ) : 1010 1010
#    34   0.78539816      (0' 0' 1  1  ) : 1010 1010
#    35   0.78539816      (2' 0' 2  2  ) : 1010 1001 1010 0110
#    36   0.78539816      (5' 0' 5  2  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    37   0.78539816      (5' 0' 5  2  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    38   0.78539816      (2' 0' 1  1  ) : 1010 1001 1010 0110
#    39   0.78539816      (5' 0' 3  3  ) : 1010 1001 1010 0110
#    40   0.78539816      (2' 0' 3  3  ) : 1010 1001 1010 0110
#    41   0.78539816      (3' 0' 5  3  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    42   0.78539816      (1' 0' 2  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    43   0.78539816      (0' 0' 4  4  ) : 1010 1010
#    44   0.78539816      (2' 0' 4  4  ) : 1010 1001 1010 0110
#    45   0.78539816      (2' 0' 5  2  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    46   0.78539816            (5' 0  ) : 00 11 00 11
#    47   0.78539816      (5' 0' 5  5  ) : 1010 1001 1010 0110
#    48   0.78539816      (2' 0' 5  5  ) : 1010 1001 1010 0110
#    49   0.78539816      (5' 0' 2  2  ) : 1010 1001 1010 0110
#    50   0.78539816      (5' 0' 4  4  ) : 1010 1001 1010 0110
#    51   0.78539816      (4' 0' 5  4  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    52   0.78539816      (1' 0' 5  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    53   0.78539816      (3' 0' 3  2  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    54   0.78539816      (5' 0' 5  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    55   0.78539816      (0' 0' 2  1  ) : 1010 0110 1010 1001
#    56   0.78539816            (1' 0  ) : 00 11 00 11
#    57   0.78539816      (5' 0' 5  1  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    58   0.78539816      (1' 0' 5  5  ) : 1010 1001 1010 0110
#    59   0.78539816      (1' 0' 5  2  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    60   0.78539816      (0' 0' 5  1  ) : 1010 0110 1010 1001
#    61   0.78539816      (1' 0' 5  2  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    62   0.78539816      (1' 0' 4  4  ) : 1010 1001 1010 0110
#    63   0.78539816      (1' 0' 3  3  ) : 1010 1001 1010 0110
#    64   0.78539816      (4' 0' 5  4  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    65   0.78539816      (4' 0' 4  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    66   0.78539816      (4' 0' 4  1  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    67   0.78539816      (1' 0' 5  1  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    68   0.78539816      (4' 0' 4  2  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    69   0.78539816      (1' 0' 2  2  ) : 1010 1001 1010 0110
#    70   0.78539816      (2' 0' 5  2  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    71   0.78539816      (5' 0' 2  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    72   0.78539816      (1' 0' 2  1  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    73   0.78539816      (2' 0' 2  1  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    74   0.78539816      (2' 0' 5  1  ) : 1010 0101 1001 0110 1010 0101 0110 1001
#    75   0.78539816      (2' 0' 2  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    76   0.78539816      (2' 0' 5  1  ) : 0000 1111 1010 0101 1001 0110 0000 1111 1010 0101 0110 1001
#    77   0.78539816      (1' 0' 1  1  ) : 1010 1001 1010 0110
#    78   0.78539816      (0' 0' 1  0  ) : 1010 0110 1010 1001
#    79   0.78539816      (5' 0' 1  1  ) : 1010 1001 1010 0110
#  --------------------------------------

# %% [markdown]
# ## Plot the errors

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1)
ax.set_ylim(-16.2,1)

iter_range = list(range( 0, len(GCIM_DIFFS) ))
plt.plot(iter_range, np.log10(np.abs(GCIM_DIFFS))[iter_range],
         marker='o',markerfacecolor='none',color='purple',
         linestyle='--',linewidth=3,markersize=15, label=r'ADAPT-GCIM, $\theta = \frac{\pi}{4}$')
ax.axhspan(min(ax.get_ylim()), np.log10(1.5936e-3), alpha=0.1)
plt.xlabel(r'# of Iterations', fontweight='bold')
plt.ylabel(r'$\log_{10}\|E - E_{\rm exact}\|$', fontweight='bold')
plt.title('LiH, error from the ground-state FCI energy')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# You can see ADAPT-GCIM reach the ~$10^{-14}$ error in less than 60 iterations WITHOUT any parameter optimization.

# %% [markdown]
# ## Counting gates of ansatzes
#
# In the above computation, we still use `SciPy` to simulate the unitary evolution in quantum circuits. To estimate the quantum resources, we need to use `Qiskit`.

# %%
import qiskit
import qiskit.quantum_info as qi
import qiskit_algorithms as qalg

# %% [markdown]
# Let us say we want transfer the ansatz with Index `193` in the operator pool to a circuit. We first make it a Qiskit object from an OpenFermion object.

# %%
def format_qubit_operator(qubit_op, n_qubits, real_coeff = False):
    # qubit_op: openfermion.ops.operators.qubit_operator.QubitOperator
    # n_qubits: int
    # return e.g.,  {'YZXIIIII': 0.5j, 'XZYIIIII': -0.5j}
    imaginary_flag = False
    coefs = []
    paulis = []
    for term, term_coef in qubit_op.terms.items():
        # Create a list of 'I' for all qubits
        formatted_term = ['I'] * n_qubits
        for qubit, pauli in term:
            formatted_term[qubit] = pauli
        if real_coeff:
            if term_coef != np.imag(term_coef):
                imaginary_flag = True
            term_coef = np.imag(term_coef)
        coefs.append(term_coef)
        paulis.append(''.join(formatted_term))
    return coefs, paulis, imaginary_flag

ind = 193
jw_op = of.transforms.jordan_wigner(pool.fermi_ops[ind])
op_coefs, op_paulis, if_imag = format_qubit_operator(jw_op, n_orb*2, real_coeff = True)
qiskit_op = qi.SparsePauliOp(op_paulis, coeffs=-1*np.array(op_coefs) )
qiskit_op
# Out:
# SparsePauliOp(['IIXXIIIIIIYX', 'IIYYIIIIIIYX', 'IIYXIIIIIIXX', 'IIXYIIIIIIXX', 'IIYXIIIIIIYY', 'IIXYIIIIIIYY', 'IIXXIIIIIIXY', 'IIYYIIIIIIXY'],
#               coeffs=[ 0.08838835+0.j, -0.08838835+0.j, -0.08838835+0.j, -0.08838835+0.j,
#   0.08838835+0.j,  0.08838835+0.j,  0.08838835+0.j, -0.08838835+0.j])

# %% [markdown]
# Now, we do the evoltion of the this operator to obtain the matrix exponential using Trotter

# %%
initial_state = qi.Statevector.from_label('0'*(n_orb*2))
problem = qalg.TimeEvolutionProblem(qiskit_op, initial_state=initial_state, time=theta)
## to circuit
trotter = qalg.time_evolvers.trotterization.TrotterQRTE(num_timesteps=1)
result = trotter.evolve(problem)
result.evolved_state.decompose().draw()
# Out:
#       »
#  q_0: »
#       »
#  q_1: »
#       »
#  q_2: »
#       »
#  q_3: »
#       »
#  q_4: »
#       »
#  q_5: »
#       »
#  q_6: »
#       »
#  q_7: »
#       »
#  q_8: »
#       »
#  q_9: »
#       »
# q_10: »
#       »
# q_11: »
#       »
# «      ┌──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# « q_0: ┤0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# « q_1: ┤1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# « q_2: ┤2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# « q_3: ┤3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# « q_4: ┤4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# ...
# «q_11: ┤11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# «      └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# «      ┌────────────────────────┐┌────────────────────────┐»
# « q_0: ┤0                       ├┤0                       ├»
# «      │                        ││                        │»
# « q_1: ┤1                       ├┤1                       ├»
# «      │                        ││                        │»
# « q_2: ┤2                       ├┤2                       ├»
# «      │                        ││                        │»
# « q_3: ┤3                       ├┤3                       ├»
# «      │                        ││                        │»
# « q_4: ┤4                       ├┤4                       ├»
# «      │                        ││                        │»
# « q_5: ┤5                       ├┤5                       ├»
# «      │   exp(it IIXXIIIIIIYX) ││   exp(it IIYYIIIIIIYX) │»
# « q_6: ┤6                       ├┤6                       ├»
# «      │                        ││                        │»
# « q_7: ┤7                       ├┤7                       ├»
# «      │                        ││                        │»
# « q_8: ┤8                       ├┤8                       ├»
# «      │                        ││                        │»
# « q_9: ┤9                       ├┤9                       ├»
# «      │                        ││                        │»
# «q_10: ┤10                      ├┤10                      ├»
# «      │                        ││                        │»
# «q_11: ┤11                      ├┤11                      ├»
# «      └────────────────────────┘└────────────────────────┘»
# «      ┌────────────────────────┐┌────────────────────────┐»
# « q_0: ┤0                       ├┤0                       ├»
# «      │                        ││                        │»
# « q_1: ┤1                       ├┤1                       ├»
# «      │                        ││                        │»
# « q_2: ┤2                       ├┤2                       ├»
# «      │                        ││                        │»
# « q_3: ┤3                       ├┤3                       ├»
# «      │                        ││                        │»
# « q_4: ┤4                       ├┤4                       ├»
# «      │                        ││                        │»
# « q_5: ┤5                       ├┤5                       ├»
# «      │   exp(it IIYXIIIIIIXX) ││   exp(it IIXYIIIIIIXX) │»
# « q_6: ┤6                       ├┤6                       ├»
# «      │                        ││                        │»
# « q_7: ┤7                       ├┤7                       ├»
# «      │                        ││                        │»
# « q_8: ┤8                       ├┤8                       ├»
# «      │                        ││                        │»
# « q_9: ┤9                       ├┤9                       ├»
# «      │                        ││                        │»
# «q_10: ┤10                      ├┤10                      ├»
# «      │                        ││                        │»
# «q_11: ┤11                      ├┤11                      ├»
# «      └────────────────────────┘└────────────────────────┘»
# «      ┌────────────────────────┐┌────────────────────────┐»
# « q_0: ┤0                       ├┤0                       ├»
# «      │                        ││                        │»
# « q_1: ┤1                       ├┤1                       ├»
# «      │                        ││                        │»
# « q_2: ┤2                       ├┤2                       ├»
# «      │                        ││                        │»
# « q_3: ┤3                       ├┤3                       ├»
# «      │                        ││                        │»
# « q_4: ┤4                       ├┤4                       ├»
# «      │                        ││                        │»
# « q_5: ┤5                       ├┤5                       ├»
# «      │   exp(it IIYXIIIIIIYY) ││   exp(it IIXYIIIIIIYY) │»
# « q_6: ┤6                       ├┤6                       ├»
# «      │                        ││                        │»
# « q_7: ┤7                       ├┤7                       ├»
# «      │                        ││                        │»
# « q_8: ┤8                       ├┤8                       ├»
# «      │                        ││                        │»
# « q_9: ┤9                       ├┤9                       ├»
# «      │                        ││                        │»
# «q_10: ┤10                      ├┤10                      ├»
# «      │                        ││                        │»
# «q_11: ┤11                      ├┤11                      ├»
# «      └────────────────────────┘└────────────────────────┘»
# «      ┌────────────────────────┐┌────────────────────────┐
# « q_0: ┤0                       ├┤0                       ├
# «      │                        ││                        │
# « q_1: ┤1                       ├┤1                       ├
# «      │                        ││                        │
# « q_2: ┤2                       ├┤2                       ├
# «      │                        ││                        │
# « q_3: ┤3                       ├┤3                       ├
# «      │                        ││                        │
# « q_4: ┤4                       ├┤4                       ├
# «      │                        ││                        │
# « q_5: ┤5                       ├┤5                       ├
# «      │   exp(it IIXXIIIIIIXY) ││   exp(it IIYYIIIIIIXY) │
# « q_6: ┤6                       ├┤6                       ├
# «      │                        ││                        │
# « q_7: ┤7                       ├┤7                       ├
# «      │                        ││                        │
# « q_8: ┤8                       ├┤8                       ├
# «      │                        ││                        │
# « q_9: ┤9                       ├┤9                       ├
# «      │                        ││                        │
# «q_10: ┤10                      ├┤10                      ├
# «      │                        ││                        │
# «q_11: ┤11                      ├┤11                      ├
# «      └────────────────────────┘└────────────────────────┘

# %% [markdown]
# Finally, we transpile the circuit into basis gates and optimize the gate counts

# %%
basis_gate_set = ['cx', 'rz', 'sx']
trans_circ = qiskit.transpile(result.evolved_state, basis_gates=basis_gate_set, 
                       optimization_level=3, seed_transpiler=7)
opt_counts = dict(trans_circ.count_ops())
print(f"The matrix exponential of the ansatz index 193 requires {opt_counts['cx']} CNOT gates")
# Out:
# The matrix exponential of the ansatz index 193 requires 37 CNOT gates
# /Users/zhen002/miniconda3/envs/gcimtest/lib/python3.11/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/zhen002/miniconda3/envs/gcimtest/lib/python3.11/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
